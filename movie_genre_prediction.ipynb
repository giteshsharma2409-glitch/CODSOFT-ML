# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/content/drive/MyDrive/train_data.txt',
                  sep=':::',
                  header=None,
                  names=['id','title','genre','description'])

# %%
test = pd.read_csv('/content/drive/MyDrive/test_data.txt',
                 sep=':::',
                 header=None,
                 names=['id','title','description','genre'])

# %%
train.head()
# Out:
#    id                               title       genre  \
# 0   1       Oscar et la dame rose (2009)       drama
# 1   2                       Cupid (1997)    thriller
# 2   3   Young, Wild and Wonderful (1980)       adult
# 3   4              The Secret Sin (1915)       drama
# 4   5             The Unrecovered (2007)       drama
#
#                                          description
# 0   Listening in to a conversation between his do...
# 1   A brother and sister with a past incestuous r...
# 2   As the bus empties the students for their fie...
# 3   To help their unemployed father make ends mee...
# 4   The film's title refers not only to the un-re...

# %%
test.head()
# Out:
#    id                          title  \
# 0   1          Edgar's Lunch (1998)
# 1   2      La guerra de papá (1977)
# 2   3   Off the Beaten Track (2010)
# 3   4        Meu Amigo Hindu (2015)
# 4   5             Er nu zhai (1955)
#
#                                          description  genre
# 0   L.R. Brane loves his life - his car, his apar...    NaN
# 1   Spain, March 1964: Quico is a very naughty ch...    NaN
# 2   One year in the life of Albin and his family ...    NaN
# 3   His father has died, he hasn't spoken with hi...    NaN
# 4   Before he was known internationally as a mart...    NaN

# %%
train.isna().sum()
# Out:
# id             0
# title          0
# genre          0
# description    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                 0
# title              0
# description        0
# genre          54200
# dtype: int64

# %%
train = train.drop(['id'], axis =1)

# %%
test = test.drop(['id'], axis =1)

# %%
train['year'] = train['title'].str.extract(r'(\d{4})')

# %%
test['year'] = test['title'].str.extract(r'(\d{4})')

# %%
train['title'] = train['title'].str.replace(r'\s*\(\d{4}\)', '', regex=True).str.strip()

# %%
test['title'] = test['title'].str.replace(r'\s*\(\d{4}\)', '', regex=True).str.strip()

# %%
train.head()
# Out:
#                        title       genre  \
# 0      Oscar et la dame rose      drama
# 1                      Cupid   thriller
# 2  Young, Wild and Wonderful      adult
# 3             The Secret Sin      drama
# 4            The Unrecovered      drama
#
#                                          description  year
# 0   Listening in to a conversation between his do...  2009
# 1   A brother and sister with a past incestuous r...  1997
# 2   As the bus empties the students for their fie...  1980
# 3   To help their unemployed father make ends mee...  1915
# 4   The film's title refers not only to the un-re...  2007

# %%
train.isnull().sum()
# Out:
# title             0
# genre             0
# description       0
# year           2687
# dtype: int64

# %%
test.head()
# Out:
#                   title                                        description  \
# 0         Edgar's Lunch   L.R. Brane loves his life - his car, his apar...
# 1     La guerra de papá   Spain, March 1964: Quico is a very naughty ch...
# 2  Off the Beaten Track   One year in the life of Albin and his family ...
# 3       Meu Amigo Hindu   His father has died, he hasn't spoken with hi...
# 4            Er nu zhai   Before he was known internationally as a mart...
#
#    genre  year
# 0    NaN  1998
# 1    NaN  1977
# 2    NaN  2010
# 3    NaN  2015
# 4    NaN  1955

# %%
test.isnull().sum()
# Out:
# title              0
# description        0
# genre          54200
# year            2759
# dtype: int64

# %%
train['year'].skew()
# Out:
# np.float64(49.311571250581)

# %%
train['year'] = train['year'].astype(float)

# %%
train['year'] = train['year'].fillna(train['year'].median())

# %%
train['year'] = train['year'].astype(int)

# %%
test['year'].skew()
# Out:
# np.float64(51.10974779331058)

# %%
test['year'] = test['year'].astype(float)

# %%
test['year'] = test['year'].fillna(test['year'].median())

# %%
test['year'] = test['year'].astype(int)

# %%
train.head()
# Out:
#                        title       genre  \
# 0      Oscar et la dame rose      drama
# 1                      Cupid   thriller
# 2  Young, Wild and Wonderful      adult
# 3             The Secret Sin      drama
# 4            The Unrecovered      drama
#
#                                          description  year
# 0   Listening in to a conversation between his do...  2009
# 1   A brother and sister with a past incestuous r...  1997
# 2   As the bus empties the students for their fie...  1980
# 3   To help their unemployed father make ends mee...  1915
# 4   The film's title refers not only to the un-re...  2007

# %%
test.head()
# Out:
#                   title                                        description  \
# 0         Edgar's Lunch   L.R. Brane loves his life - his car, his apar...
# 1     La guerra de papá   Spain, March 1964: Quico is a very naughty ch...
# 2  Off the Beaten Track   One year in the life of Albin and his family ...
# 3       Meu Amigo Hindu   His father has died, he hasn't spoken with hi...
# 4            Er nu zhai   Before he was known internationally as a mart...
#
#    genre  year
# 0    NaN  1998
# 1    NaN  1977
# 2    NaN  2010
# 3    NaN  2015
# 4    NaN  1955

# %%
print(train['genre'].value_counts())
# Out:
# genre
# drama           13613
# documentary     13096
# comedy           7447
# short            5073
# horror           2204
# thriller         1591
# action           1315
# western          1032
# reality-tv        884
# family            784
# adventure         775
# music             731
# romance           672
# sci-fi            647
# adult             590
# crime             505
# animation         498
# sport             432
# talk-show         391
# fantasy           323
# mystery           319
# musical           277
# biography         265
# history           243
# game-show         194
# news              181
# war               132
# Name: count, dtype: int64

# %%
x_train=train.drop('genre',axis=1)
y_train=train['genre']

x_test=test.drop('genre',axis=1)
y_test=test['genre']

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 23.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

def lemmatize_text(text):
    if isinstance(text, str):
        doc = nlp(text)
        return ' '.join([token.lemma_ for token in doc])
    return text

# Apply lemmatization to the 'description' column
x_train['description'] = x_train['description'].apply(lemmatize_text)
x_test['description'] = x_test['description'].apply(lemmatize_text)

# %%
x_train.head()
# Out:
#                        title  \
# 0      Oscar et la dame rose
# 1                      Cupid
# 2  Young, Wild and Wonderful
# 3             The Secret Sin
# 4            The Unrecovered
#
#                                          description  year
# 0    listen in to a conversation between his doct...  2009
# 1    a brother and sister with a past incestuous ...  1997
# 2    as the bus empty the student for their field...  1980
# 3    to help their unemployed father make end mee...  1915
# 4    the film 's title refer not only to the un -...  2007

# %%
x_test.head()
# Out:
#                   title                                        description  \
# 0         Edgar's Lunch    L.R. Brane love his life - his car , his apa...
# 1     La guerra de papá    Spain , March 1964 : Quico be a very naughty...
# 2  Off the Beaten Track    one year in the life of Albin and his family...
# 3       Meu Amigo Hindu    his father have die , he have not speak with...
# 4            Er nu zhai    before he be know internationally as a marti...
#
#    year
# 0  1998
# 1  1977
# 2  2010
# 3  2015
# 4  1955

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer with ngram_range (1, 3)
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 3), max_features=20000) # Limiting max_features to avoid excessive memory usage, can be adjusted

# Fit on x_train['description'] and transform both x_train and x_test
X_train_tfidf = tfidf_vectorizer.fit_transform(x_train['description'])
X_test_tfidf = tfidf_vectorizer.transform(x_test['description'])

# %%
print(f'Shape of X_train_tfidf: {X_train_tfidf.shape}')
print(f'Shape of X_test_tfidf: {X_test_tfidf.shape}')
# Out:
# Shape of X_train_tfidf: (54214, 20000)
# Shape of X_test_tfidf: (54200, 20000)

# %%
from sklearn.feature_selection import SelectKBest, chi2

# Select top K features based on chi2 score
k_features = 10000  # You can adjust this number
selector = SelectKBest(chi2, k=k_features)

# Fit on training data and transform both training and test data
X_train_selected = selector.fit_transform(X_train_tfidf, y_train)
X_test_selected = selector.transform(X_test_tfidf)

# %%
print(f'Shape of X_train_selected: {X_train_selected.shape}')
print(f'Shape of X_test_selected: {X_test_selected.shape}')
# Out:
# Shape of X_train_selected: (54214, 10000)
# Shape of X_test_selected: (54200, 10000)

# %%
# Install imblearn library if not already installed
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_selected, y_train)

# %%
print(f'Shape of X_train_resampled: {X_train_resampled.shape}')
print(f'Shape of y_train_resampled: {y_train_resampled.shape}')
print('\nValue counts of y_train_resampled after SMOTE:')
print(y_train_resampled.value_counts())
# Out:
# Shape of X_train_resampled: (367551, 10000)
# Shape of y_train_resampled: (367551,)
#
# Value counts of y_train_resampled after SMOTE:
# genre
# drama           13613
# thriller        13613
# adult           13613
# documentary     13613
# comedy          13613
# crime           13613
# reality-tv      13613
# horror          13613
# sport           13613
# animation       13613
# action          13613
# fantasy         13613
# short           13613
# sci-fi          13613
# music           13613
# adventure       13613
# talk-show       13613
# western         13613
# family          13613
# mystery         13613
# history         13613
# news            13613
# biography       13613
# romance         13613
# game-show       13613
# musical         13613
# war             13613
# Name: count, dtype: int64

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Initialize LinearSVC model
linear_svm = LinearSVC(random_state=42, dual=False) # dual=False is recommended for n_samples > n_features

# %%
# Define the parameter grid for GridSearchCV
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100]  # Regularization parameter
}

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(linear_svm, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# %%
print("Starting GridSearchCV for Linear SVM...")
# Fit GridSearchCV on the resampled training data
grid_search.fit(X_train_resampled, y_train_resampled)

print("GridSearchCV completed.")

# Print the best parameters and best score
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best cross-validation accuracy: {grid_search.best_score_:.4f}")

# Get the best model
best_linear_svm_model = grid_search.best_estimator_
# Out:
# Starting GridSearchCV for Linear SVM...
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV completed.
# Best parameters found: {'C': 10}
# Best cross-validation accuracy: 0.9526

# %%
y_pred = best_linear_svm_model.predict(X_test_selected)

# %%
y_pred_series = pd.Series(y_pred)
print("\nDistribution of Predicted Genres:")
print(y_pred_series.value_counts())
# Out:
# Distribution of Predicted Genres:
# documentary     13096
# drama           12127
# comedy           7573
# short            5503
# horror           2390
# thriller         2006
# action           1578
# western          1110
# reality-tv       1014
# adventure         829
# family            817
# romance           803
# music             780
# sci-fi            643
# adult             565
# animation         509
# crime             473
# sport             415
# talk-show         323
# fantasy           315
# mystery           249
# musical           244
# biography         225
# history           202
# game-show         179
# news              137
# war                95
# Name: count, dtype: int64

# %%
new_input_text = input("Enter the text you want to classify: ")

# Preprocess the new input text
lemmatized_input = lemmatize_text(new_input_text)

# Transform the lemmatized text using the fitted TF-IDF vectorizer
input_tfidf = tfidf_vectorizer.transform([lemmatized_input])

# Select features using the fitted selector
input_selected = selector.transform(input_tfidf)

# Predict the genre using the best model
predicted_genre = best_linear_svm_model.predict(input_selected)

print(f"The predicted genre for the input text is: {predicted_genre[0]}")
# Out:
# Enter the text you want to classify: Knight fought with dragons and save princess from evil sorcerer.
# The predicted genre for the input text is:  animation
